# %%
import pandas as pd
import seaborn as sn
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
import tensorflow as tf
import numpy as np
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing import sequence
from tensorflow.keras.models import Model
from tensorflow.keras.layers import LSTM, Activation, Dense, Dropout, Input, Embedding, Flatten, Add, Conv1D, Layer
from tensorflow.keras.optimizers import RMSprop, Adam, Adadelta, Adagrad, Adamax, Ftrl, Nadam, SGD
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
from tensorflow.keras.metrics import Accuracy
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.losses import CategoricalCrossentropy
from scipy.signal import savgol_filter
import matplotlib.pyplot as plt
from tensorflow_addons.metrics import F1Score
from tensorflow_addons.optimizers import AdamW
from tensorflow_addons.losses import SigmoidFocalCrossEntropy
from transformers import AutoTokenizer, TFAutoModel, AutoModelForSequenceClassification, TFAutoModelForSequenceClassification
from tensorflow.nn import softmax as tf_softmax
import nltk
from nltk.stem import WordNetLemmatizer 
# %matplotlib inline

# %%
def is_interactive():
    return 'runtime' in get_ipython().config.IPKernelApp.connection_file

print('Interactive: ', is_interactive())
# Out:
# Interactive:  True

# %%
# Detect hardware, return appropriate distribution strategy
try:
    tpu = tf.distribute.cluster_resolver.TPUClusterResolver()  # TPU detection
    print('Running on TPU ', tpu.cluster_spec().as_dict()['worker'])
except ValueError:
    tpu = None

if tpu:
    tf.config.experimental_connect_to_cluster(tpu)
    tf.tpu.experimental.initialize_tpu_system(tpu)
    strategy = tf.distribute.experimental.TPUStrategy(tpu)
else:
    # Default distribution strategy in Tensorflow. Works on CPU and single GPU.
    strategy = tf.distribute.get_strategy()

print("REPLICAS: ", strategy.num_replicas_in_sync)
# Out:
# REPLICAS:  1

# %%
task = 'a' # a,b,c
keys_for_task = {'a':'label_sexist','b':'label_category','c':'label_vector'}
key_for_task = keys_for_task[task]

# %%
task = 'b' # a,b,c
keys_for_task = {'a':'label_sexist','b':'label_category','c':'label_vector'}
key_for_task = keys_for_task[task]

# %% [markdown]
# # **DATA PREPROCESSING**

# %%
df = pd.read_csv('path/train_all_tasks.csv',delimiter=',',encoding='utf-8')
df.head()
# Out:
#                   rewire_id  \
# 0   sexism2022_english-7358
# 1   sexism2022_english-2367
# 2   sexism2022_english-3073
# 3  sexism2022_english-14895
# 4   sexism2022_english-4118
#
#                                                 text label_sexist  \
# 0              Damn, this writing was pretty chaotic   not sexist
# 1  Yeah, and apparently a bunch of misogynistic v...   not sexist
# 2       How the FUCK is this woman still an MP!!!???   not sexist
# 3  Understand. Know you're right. At same time I ...   not sexist
# 4     Surprized they didn't stop and rape some women   not sexist
#
#   label_category label_vector
# 0           none         none
# 1           none         none
# 2           none         none
# 3           none         none
# 4           none         none

# %%
nltk.download('wordnet')
nltk.download('omw-1.4')

lemmatizer = WordNetLemmatizer()

def lemmatize(sentence):
    return ' '.join([lemmatizer.lemmatize(word) for word in sentence.split(' ')])
# Out:
# [nltk_data] Downloading package wordnet to /usr/share/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /usr/share/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!

# %%
df['text'] = df['text'].map(lambda sentence:lemmatize(sentence))
df.head()
# Out:
#                   rewire_id  \
# 0   sexism2022_english-7358
# 1   sexism2022_english-2367
# 2   sexism2022_english-3073
# 3  sexism2022_english-14895
# 4   sexism2022_english-4118
#
#                                                 text label_sexist  \
# 0               Damn, this writing wa pretty chaotic   not sexist
# 1  Yeah, and apparently a bunch of misogynistic v...   not sexist
# 2       How the FUCK is this woman still an MP!!!???   not sexist
# 3  Understand. Know you're right. At same time I ...   not sexist
# 4     Surprized they didn't stop and rape some woman   not sexist
#
#   label_category label_vector
# 0           none         none
# 1           none         none
# 2           none         none
# 3           none         none
# 4           none         none

# %%
df.drop(['rewire_id'],axis=1,inplace=True)
df.head()
# Out:
#                                                 text label_sexist  \
# 0               Damn, this writing wa pretty chaotic   not sexist
# 1  Yeah, and apparently a bunch of misogynistic v...   not sexist
# 2       How the FUCK is this woman still an MP!!!???   not sexist
# 3  Understand. Know you're right. At same time I ...   not sexist
# 4     Surprized they didn't stop and rape some woman   not sexist
#
#   label_category label_vector
# 0           none         none
# 1           none         none
# 2           none         none
# 3           none         none
# 4           none         none

# %%
def count_plot(df, name, key_count = key_for_task):
    print(df.info())
    sn.countplot(data=df, x=key_count)
    plt.xticks(rotation = 90)
    plt.savefig(name)
    plt.show()
    
count_plot(df,"distribution.svg")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14000 entries, 0 to 13999
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   text            14000 non-null  object
#  1   label_sexist    14000 non-null  object
#  2   label_category  14000 non-null  object
#  3   label_vector    14000 non-null  object
# dtypes: object(4)
# memory usage: 437.6+ KB
# None

# %%
from scipy.signal import savgol_filter

# Assuming 'df' is your DataFrame and 'plt' is matplotlib.pyplot imported earlier

lens = df.text.str.len().value_counts()
count_plot = pd.DataFrame({'leng':lens.index, 'freq':lens.values}).sort_values('leng')

plt.plot(count_plot.leng, count_plot.freq, color='blue')  # Blue color for the original plot
plt.plot(count_plot.leng, savgol_filter(count_plot.freq, 51, 3), color='red')  # Orange color for the smoothed plot

plt.xlabel('Length')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# # **LABEL ENCODING**

# %%
label_encoder = LabelEncoder()

# label encoding

X = df['text']
Y = df[key_for_task]
Y = label_encoder.fit_transform(Y)

# %%
label_encoder_mapping = dict(zip(label_encoder.classes_, label_encoder.transform(label_encoder.classes_)))
print(label_encoder_mapping)
inverse_label_encoder_mapping = {label_encoder_mapping[k]:k for k in label_encoder_mapping}
print(inverse_label_encoder_mapping)

NUM_CLASS = len(label_encoder_mapping)
# Out:
# {'1. threats, plans to harm and incitement': 0, '2. derogation': 1, '3. animosity': 2, '4. prejudiced discussions': 3, 'none': 4}
# {0: '1. threats, plans to harm and incitement', 1: '2. derogation', 2: '3. animosity', 3: '4. prejudiced discussions', 4: 'none'}

# %%
# one hot encoding

Y = tf.keras.utils.to_categorical(Y, num_classes=NUM_CLASS)

# %%
DEBUG_EPOCH = 20 

EPOCH = DEBUG_EPOCH if is_interactive() else 180
print(EPOCH)

LEARNING_RATE = 5e-5
WEIGHT_DECAY = 1e-2
# Out:
# 20

# %% [markdown]
# # **SENTENCE TRANSFORMATION**

# %%
# "sentence-transformers/all-MiniLM-L6-v2"
## https://huggingface.co/sentence-transformers/all-MiniLM-L6-v2

class Sentence2Sentence(Layer):
    def __init__(self, **kwargs):
        super(Sentence2Sentence, self).__init__(**kwargs)

        pre_name = "sentence-transformers/all-MiniLM-L6-v2"
        self.tokenizer = AutoTokenizer.from_pretrained(pre_name)
        self.model = TFAutoModel.from_pretrained(pre_name)

        
    def tf_encode(self, inputs):
        def encode(inputs):
            inputs = [x[0].decode('utf-8') for x in inputs.numpy()]
            outputs = self.tokenizer(inputs, padding=True, truncation=True, return_tensors='tf')
            return (outputs['input_ids'], outputs['token_type_ids'], outputs['attention_mask'])

        return tf.py_function(func=encode, inp=[inputs], Tout=[tf.int32, tf.int32, tf.int32])

    def process(self,i,t,a):

        def __call(i, t, a):
            model_output = self.model({'input_ids': i.numpy(),'token_type_ids': t.numpy(),'attention_mask': a.numpy()})
            return model_output[0]

        return tf.py_function(func=__call, inp=[i, t, a], Tout=[tf.float32])

    def mean_pooling(self, model_output, attention_mask):
        token_embeddings = tf.squeeze(tf.stack(model_output), axis=0)
        input_mask_expanded = tf.cast(tf.broadcast_to(tf.expand_dims(attention_mask, -1),tf.shape(token_embeddings)), tf.float32)
        a = tf.math.reduce_sum(token_embeddings * input_mask_expanded, axis=1)
        b = tf.clip_by_value(tf.math.reduce_sum(input_mask_expanded, axis=1), 1e-9, tf.float32.max)
        embeddings = a / b
        (embeddings, _) = tf.linalg.normalize(embeddings, 2, axis=1)
        return embeddings

    def call(self, inputs):
        (input_ids, token_type_ids, attention_mask) = self.tf_encode(inputs)
        input_ids.set_shape(tf.TensorShape((None, None)))
        token_type_ids.set_shape(tf.TensorShape((None, None)))
        attention_mask.set_shape(tf.TensorShape((None, None)))

        model_output = self.process(input_ids, token_type_ids,attention_mask)
        
        model_output[0].set_shape(tf.TensorShape((None, None, 384)))
        embeddings = self.mean_pooling(model_output, attention_mask)
        # Reshape embeddings to have a third dimension
        embeddings = tf.expand_dims(embeddings, axis=-1)
        return embeddings

# %%
class StringLowerLayer(Layer):
    def __init__(self, **kwargs):
        super(StringLowerLayer, self).__init__(**kwargs)
        
    def call(self, inputs):
        return tf.strings.lower(inputs)

# %%
class StressLayer(Layer):
    def __init__(self, **kwargs):
        super(StressLayer, self).__init__(**kwargs)

# %% [markdown]
# # **MODEL ARCHITECTURE**

# %%
from tensorflow.keras.layers import Input, Conv1D, MaxPooling1D, Flatten, Dense, Dropout, LSTM, Attention
from tensorflow.keras.models import Model

def get_model():
    # Input layer
    input_layer = Input(shape=(1,), dtype=tf.string,)
    sentence_layer = Sentence2Sentence()(input_layer)
    
    # Convolutional layers
    conv1 = Conv1D(filters=128, kernel_size=5, activation='relu')(sentence_layer)
    pool1 = MaxPooling1D(pool_size=2)(conv1)
    conv2 = Conv1D(filters=64, kernel_size=3, activation='relu')(pool1)
    pool2 = MaxPooling1D(pool_size=2)(conv2)
    conv3 = Conv1D(filters=32, kernel_size=2, activation='relu')(pool2)
    pool3 = MaxPooling1D(pool_size=2)(conv3)

    # LSTM layer
    lstm_layer = LSTM(64, return_sequences=True)(pool3)

    # Self-Attention layer
    attention_output = Attention()([lstm_layer, lstm_layer])

    # Flatten layer
    flatten_layer = Flatten()(attention_output)

    # Dense layers
    dense1 = Dense(128, activation='relu')(flatten_layer)
    dropout1 = Dropout(0.5)(dense1)
    dense2 = Dense(64, activation='relu')(dropout1)
    dropout2 = Dropout(0.5)(dense2)
    output_layer = Dense(NUM_CLASS, activation='softmax')(dropout2)

    model = Model(inputs=input_layer, outputs=output_layer)
    optimizer = Adam(learning_rate=LEARNING_RATE)
    model.compile(
        loss='binary_crossentropy',
        optimizer=optimizer,
        metrics=['accuracy',
            F1Score(num_classes=NUM_CLASS,average='weighted'),
        ],
    )
    
    return model

# %%
model = get_model()
# Out:
# All model checkpoint layers were used when initializing TFBertModel.
#
# All the layers of TFBertModel were initialized from the model checkpoint at sentence-transformers/all-MiniLM-L6-v2.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFBertModel for predictions without further training.

# %%
model.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            [(None, 1)]          0
# __________________________________________________________________________________________________
# sentence2_sentence_2 (Sentence2 (None, 384, 1)       22713216    input_3[0][0]
# __________________________________________________________________________________________________
# conv1d_6 (Conv1D)               (None, 380, 128)     768         sentence2_sentence_2[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_6 (MaxPooling1D)  (None, 190, 128)     0           conv1d_6[0][0]
# __________________________________________________________________________________________________
# conv1d_7 (Conv1D)               (None, 188, 64)      24640       max_pooling1d_6[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_7 (MaxPooling1D)  (None, 94, 64)       0           conv1d_7[0][0]
# __________________________________________________________________________________________________
# conv1d_8 (Conv1D)               (None, 93, 32)       4128        max_pooling1d_7[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_8 (MaxPooling1D)  (None, 46, 32)       0           conv1d_8[0][0]
# __________________________________________________________________________________________________
# lstm_2 (LSTM)                   (None, 46, 64)       24832       max_pooling1d_8[0][0]
# __________________________________________________________________________________________________
# attention_2 (Attention)         (None, 46, 64)       0           lstm_2[0][0]
#                                                                  lstm_2[0][0]
# __________________________________________________________________________________________________
# flatten_2 (Flatten)             (None, 2944)         0           attention_2[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 128)          376960      flatten_2[0][0]
# __________________________________________________________________________________________________
# dropout_61 (Dropout)            (None, 128)          0           dense_6[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 64)           8256        dropout_61[0][0]
# __________________________________________________________________________________________________
# dropout_62 (Dropout)            (None, 64)           0           dense_7[0][0]
# __________________________________________________________________________________________________
# dense_8 (Dense)                 (None, 5)            325         dropout_62[0][0]
# ==================================================================================================
# Total params: 23,153,125
# Trainable params: 23,153,125
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
tf.keras.utils.plot_model(model, to_file='model.png',expand_nested=True,show_shapes=True,dpi=None,)
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)

# %% [markdown]
# # **SPLIT AND REGULARIZATION**

# %%
lr_reducer = ReduceLROnPlateau(monitor='val_loss', factor=0.1,patience=10)
early_stopping_callback = EarlyStopping(monitor='val_loss',min_delta=0,patience=30,verbose=0, mode='auto')
model_saver = ModelCheckpoint(filepath='model.h5', save_best_only=True)

callbacks = [early_stopping_callback, lr_reducer,model_saver]

# %%
SHUFFLE_DS = 1024
BATCH_SIZE_DS = 16 * strategy.num_replicas_in_sync
AUTO = tf.data.experimental.AUTOTUNE

if task == 'a':
    train_X, val_X, train_Y, val_Y = train_test_split(X, Y, test_size=0.3, stratify=Y)
else:
    train_X, val_X, train_Y, val_Y = train_test_split(X, Y, test_size=0.3)


# train_ds = tf.data.Dataset.from_tensor_slices((train_X, train_Y)).repeat().shuffle(SHUFFLE_DS).batch(BATCH_SIZE_DS).prefetch(AUTO)
# val_ds = tf.data.Dataset.from_tensor_slices((val_X, val_Y)).repeat().shuffle(SHUFFLE_DS).batch(BATCH_SIZE_DS).prefetch(AUTO)
    
N_STEPS = len(train_X) / BATCH_SIZE_DS

# %% [markdown]
# # **MODEL INFERENCE**

# %%
history_model = model.fit(train_X, train_Y,epochs=20,validation_data=(val_X, val_Y), callbacks=callbacks, steps_per_epoch = N_STEPS)
# Out:
# Epoch 1/20
# 612/612 [==============================] - 69s 109ms/step - loss: 0.4417 - accuracy: 0.6187 - f1_score: 0.6033 - val_loss: 0.3050 - val_accuracy: 0.7455 - val_f1_score: 0.6368
# Epoch 2/20
# 612/612 [==============================] - 66s 107ms/step - loss: 0.3596 - accuracy: 0.7347 - f1_score: 0.6521 - val_loss: 0.3000 - val_accuracy: 0.7455 - val_f1_score: 0.6368
# Epoch 3/20
# 612/612 [==============================] - 66s 107ms/step - loss: 0.3392 - accuracy: 0.7520 - f1_score: 0.6585 - val_loss: 0.2951 - val_accuracy: 0.7455 - val_f1_score: 0.6368
# Epoch 4/20
# 612/612 [==============================] - 66s 107ms/step - loss: 0.3308 - accuracy: 0.7540 - f1_score: 0.6562 - val_loss: 0.2933 - val_accuracy: 0.7455 - val_f1_score: 0.6368
# Epoch 5/20
# 612/612 [==============================] - 66s 108ms/step - loss: 0.3236 - accuracy: 0.7588 - f1_score: 0.6586 - val_loss: 0.2920 - val_accuracy: 0.7455 - val_f1_score: 0.6368
# Epoch 6/20
# 612/612 [==============================] - 67s 109ms/step - loss: 0.3193 - accuracy: 0.7604 - f1_score: 0.6593 - val_loss: 0.2914 - val_accuracy: 0.7455 - val_f1_score: 0.6368
# Epoch 7/20
# 612/612 [==============================] - 66s 108ms/step - loss: 0.3134 - accuracy: 0.7612 - f1_score: 0.6591 - val_loss: 0.2912 - val_accuracy: 0.7455 - val_f1_score: 0.6368
# Epoch 8/20
# 612/612 [==============================] - 66s 108ms/step - loss: 0.3109 - accuracy: 0.7619 - f1_score: 0.6595 - val_loss: 0.2903 - val_accuracy: 0.7455 - val_f1_score: 0.6368
# Epoch 9/20
# 612/612 [==============================] - 65s 107ms/step - loss: 0.3102 - accuracy: 0.7620 - f1_score: 0.6594 - val_loss: 0.2902 - val_accuracy: 0.7455 - val_f1_score: 0.6368
# Epoch 10/20
# 612/612 [==============================] - 66s 107ms/step - loss: 0.3071 - accuracy: 0.7622 - f1_score: 0.6595 - val_loss: 0.2900 - val_accuracy: 0.7455 - val_f1_score: 0.6368
# Epoch 11/20
# 612/612 [==============================] - 66s 108ms/step - loss: 0.3048 - accuracy: 0.7623 - f1_score: 0.6595 - val_loss: 0.2904 - val_accuracy: 0.7455 - val_f1_score: 0.6368
# Epoch 12/20
# 612/612 [==============================] - 65s 106ms/step - loss: 0.3050 - accuracy: 0.7623 - f1_score: 0.6595 - val_loss: 0.2896 - val_accuracy: 0.7455 - val_f1_score: 0.6368
# Epoch 13/20
# 612/612 [==============================] - 66s 107ms/step - loss: 0.3019 - accuracy: 0.7623 - f1_score: 0.6595 - val_loss: 0.2895 - val_accuracy: 0.7455 - val_f1_score: 0.6368
# Epoch 14/20
# 612/612 [==============================] - 66s 108ms/step - loss: 0.2993 - accuracy: 0.7623 - f1_score: 0.6595 - val_loss: 0.2900 - val_accuracy: 0.7455 - val_f1_score: 0.6368
# Epoch 15/20
# 612/612 [==============================] - 66s 107ms/step - loss: 0.3002 - accuracy: 0.7623 - f1_score: 0.6595 - val_loss: 0.2897 - val_accuracy: 0.7455 - val_f1_score: 0.6368
# Epoch 16/20
# 612/612 [==============================] - 65s 106ms/step - loss: 0.2990 - accuracy: 0.7623 - f1_score: 0.6595 - val_loss: 0.2902 - val_accuracy: 0.7455 - val_f1_score: 0.6368
# Epoch 17/20
# 612/612 [==============================] - 66s 107ms/step - loss: 0.2991 - accuracy: 0.7623 - f1_score: 0.6595 - val_loss: 0.2892 - val_accuracy: 0.7455 - val_f1_score: 0.6368
# Epoch 18/20
# 612/612 [==============================] - 66s 107ms/step - loss: 0.2993 - accuracy: 0.7623 - f1_score: 0.6595 - val_loss: 0.2891 - val_accuracy: 0.7455 - val_f1_score: 0.6368
# Epoch 19/20
# 612/612 [==============================] - 66s 107ms/step - loss: 0.2965 - accuracy: 0.7623 - f1_score: 0.6595 - val_loss: 0.2890 - val_accuracy: 0.7455 - val_f1_score: 0.6368
# Epoch 20/20
# 612/612 [==============================] - 65s 107ms/step - loss: 0.2964 - accuracy: 0.7623 - f1_score: 0.6595 - val_loss: 0.2890 - val_accuracy: 0.7455 - val_f1_score: 0.6368

# %%
# !mkdir history
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# mkdir: cannot create directory ‘history’: File exists

# %%
with open('history/history.json','w') as f:
    f.write(str(history_model.history))

# %%
# !mkdir figures
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# mkdir: cannot create directory ‘figures’: File exists

# %%
import pandas as pd

def capitalize(string):
    string = string.replace("_", " ")
    return string.title()

def plot_graphs(data, keys):
    # Convert history data to DataFrame
    df_history = pd.DataFrame(data)
    
    # Display the DataFrame
    print("History Data:")
    print(df_history)
    print("\n")
    
    # Plotting
    fig, axes = plt.subplots(1, (len(keys) + 1), figsize=(16, 5))
    plt.legend(loc='best')
    
    for i in range(len(keys)):
        df_graph = pd.DataFrame({x: data[x] for x in data if keys[i] in x})
        df_keys = [x for x in data if keys[i] in x]
        df_graph[df_keys].plot(ax=axes[i])
        axes[i].set_title(capitalize(keys[i]))
        
    last_index = len(keys)
    all_keys = [x for x in data if x]
    
    df_combined = pd.DataFrame({x: data[x] for x in data})
    df_combined[all_keys].plot(ax=axes[last_index])
    axes[len(keys)].set_title('Combined')
    
    plt.tight_layout()
    
    plt.savefig('figures/figure_optimizer.svg')
    plt.show()

# Assuming 'history_model.history' contains the data
plot_graphs(data=history_model.history, keys=['f1_score', 'loss', 'lr'])
# Out:
# History Data:
#         loss  accuracy  f1_score  val_loss  val_accuracy  val_f1_score  \
# 0   0.441749  0.618673  0.603339  0.304973      0.745476      0.636772
# 1   0.359622  0.734694  0.652143  0.300020      0.745476      0.636772
# 2   0.339240  0.752041  0.658546  0.295119      0.745476      0.636772
# 3   0.330760  0.753980  0.656192  0.293305      0.745476      0.636772
# 4   0.323602  0.758776  0.658574  0.292004      0.745476      0.636772
# 5   0.319252  0.760408  0.659271  0.291377      0.745476      0.636772
# 6   0.313350  0.761225  0.659069  0.291243      0.745476      0.636772
# 7   0.310852  0.761939  0.659458  0.290347      0.745476      0.636772
# 8   0.310215  0.762041  0.659432  0.290185      0.745476      0.636772
# 9   0.307093  0.762245  0.659494  0.290033      0.745476      0.636772
# 10  0.304783  0.762347  0.659544  0.290395      0.745476      0.636772
# 11  0.304998  0.762347  0.659544  0.289617      0.745476      0.636772
# 12  0.301858  0.762347  0.659544  0.289545      0.745476      0.636772
# 13  0.299271  0.762347  0.659544  0.290001      0.745476      0.636772
# 14  0.300163  0.762347  0.659544  0.289683      0.745476      0.636772
# 15  0.299010  0.762347  0.659544  0.290228      0.745476      0.636772
# 16  0.299058  0.762347  0.659544  0.289231      0.745476      0.636772
# 17  0.299348  0.762347  0.659544  0.289135      0.745476      0.636772
# 18  0.296453  0.762347  0.659544  0.289000      0.745476      0.636772
# 19  0.296443  0.762347  0.659544  0.289027      0.745476      0.636772
#
#          lr
# 0   0.00005
# 1   0.00005
# 2   0.00005
# 3   0.00005
# 4   0.00005
# 5   0.00005
# 6   0.00005
# 7   0.00005
# 8   0.00005
# 9   0.00005
# 10  0.00005
# 11  0.00005
# 12  0.00005
# 13  0.00005
# 14  0.00005
# 15  0.00005
# 16  0.00005
# 17  0.00005
# 18  0.00005
# 19  0.00005
